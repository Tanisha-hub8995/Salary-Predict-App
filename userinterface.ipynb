# %%
import streamlit as st

import numpy as np
import joblib
import matplotlib.pyplot as plt
st.title("Salary Estimation App💸")

st.divider()

years_at_company = st.number_input("Enter years at company",value=1,step=1, min_value = 0)
Job_Rate = st.number_input("Job Rate", value=3.5,step=0.5,min_value =0.0)

X = [years_at_company, Job_Rate]


model = joblib.load("linearmodel.pkl")

predict_button = st.button("Press for predicting the salary")



st.divider()
if predict_button:

    st.balloons()
    X1 = np.array([X])

    prediction = model.predict(X1)[0]
    st.divider()
    st.subheader("Visualization📊")

    fig, ax= plt.subplots()
    ax.bar(["Predicted Salary"],[prediction],color="indigo")
    ax.set_ylabel("salary")
    ax.set_title("Your predicted salary")
    st.pyplot(fig)

    
    

    st.write(f"Salary prediction is {prediction:,.2f}")





else:
    st.write("Please enter the value and press to the predit button")
# Out:
# 2025-11-12 23:12:06.797 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.782
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\tanis\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-12 23:12:09.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.936 Session state does not function when running a script without `streamlit run`
# 2025-11-12 23:12:09.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:09.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:10.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:10.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:10.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:10.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 23:12:22.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run userinterface.py
