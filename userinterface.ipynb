# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
st.title("Salary Estimation App💸")

st.divider()
st.subheader("Enter Input for Prediction🔎")

years_at_company = st.number_input("Enter years at company",value=1,step=1, min_value = 0)
Job_Rate = st.number_input("Job Rate", value=3.5,step=0.5,min_value =0.0)


X = [years_at_company, Job_Rate]


model = joblib.load("linearmodel.pkl")

predict_button = st.button("Press for predicting the salary")



st.divider()
if predict_button:

    st.balloons()
    X1 = np.array([X])

    prediction = model.predict(X1)[0]
    st.divider()
    st.subheader("Visualization📊")

    fig, ax= plt.subplots()
    ax.bar(["Predicted Salary"],[prediction],color="indigo")
    ax.set_ylabel("salary")
    ax.set_title("Your predicted salary")
    st.pyplot(fig)

    
    

    st.write(f"Salary prediction is {prediction:,.2f}")
    st.divider()
try:
    data = pd.read_csv("C:/Users/tanis/Desktop/Employees.csv")
    st.sidebar.subheader("Dataset Preview⬇️")
    st.sidebar.write(data.head())
except FileNotFoundError:
    st.sidebar.error("Salary.csv not found. Cannot display dataset preview.")






else:
    st.write("Please enter the value and press to the predit button")
# Out:
# 2025-11-14 00:10:22.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:22.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 00:10:23.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run userinterface.py

# %%
c:/Users/tanis/Desktop/Salarypreditor/streamlit/Scripts/python.exe -m pip install ipykernel -U --force-reinstall
